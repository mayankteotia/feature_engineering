# %% [raw]
# 1. What is a parameter?
#
# ans = A parameter is a value or setting that influences how a model makes predictions. For example, in a linear regression model, the slope (m) and intercept (b) are parameters that determine the line's position.
#
# 2. What is correlation?
#
# ans = Correlation measures the strength and direction of the relationship between two variables. It ranges from -1 (strong negative) to +1 (strong positive).
#
# 3. What does negative correlation mean?
#
# ans = A negative correlation means that when one variable increases, the other tends to decrease. For example, as temperature increases, the sale of jackets decreases.
#
# 4. Define Machine Learning. What are the main components in Machine Learning?
#
# ans = Machine Learning is a field of AI that allows systems to learn patterns from data and make predictions or decisions.
# The main components are:
#
# Data
#
# Model (Algorithm)
#
# Training
#
# Prediction/Inference
#
# Evaluation
#
# 5. How does loss value help in determining whether the model is good or not?
#
# ans= The loss value tells us how far off our model's predictions are from the actual data. A lower loss means better performance.
#
# 6. What are continuous and categorical variables?
#
# ans = Continuous variables are numeric values that can take any number within a range (e.g., height, weight).
#
# Categorical variables are data grouped into categories or labels (e.g., color, gender).
#
# 7. How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# ans = We convert categorical variables into numbers using:
#
# Label Encoding (assigns a unique number to each category)
#
# One-Hot Encoding (creates a new column for each category with 0s and 1s)
#
# 8. What do you mean by training and testing a dataset?
#
# ans = Training data is used to build and learn the model.
#
# Testing data is used to check how well the model performs on new, unseen data.
#
# 9. What is sklearn.preprocessing?
#
# ans = sklearn.preprocessing is a module in scikit-learn that provides tools for preparing data, like scaling, encoding, and transforming features.
#
# 10. What is a Test set?
# A Test set is a portion of the data used after training to evaluate the model's performance on new, unseen data.
#
# 11. How do we split data for model fitting (training and testing) in Python?
# We use train_test_split() from scikit-learn:
#
# python
# Copy
# Edit
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# 12. How do you approach a Machine Learning problem?
# Step-by-step:
#
# Understand the problem.
#
# Collect and clean data.
#
# Perform EDA (Exploratory Data Analysis).
#
# Choose a model.
#
# Train the model.
#
# Evaluate the model.
#
# Improve based on results.
#
# 13. Why do we have to perform EDA before fitting a model to the data?
# EDA helps us:
#
# Understand patterns and relationships.
#
# Find missing values or outliers.
#
# Choose the right model and features.
#
# 14. What is correlation?
# Correlation is a measure of how two variables move together. A value close to +1 or -1 means strong correlation.
#
# 15. What does negative correlation mean?
# A negative correlation means as one variable increases, the other decreases. For example, more studying leads to less free time.
#
# 16. How can you find correlation between variables in Python?
# Use the .corr() function in Pandas:
#
#
# import pandas as pd
# df.corr()
# 17. What is causation? Explain difference between correlation and causation with an example.
# Causation means one variable directly causes the change in another.
# Example:
#
# Correlation: Ice cream sales and drowning deaths are correlated.
#
# Causation: Hot weather causes both. Ice cream doesn't cause drowning!
#
# 18. What is an Optimizer? What are different types of optimizers? Explain each with an example.
# An Optimizer updates the model’s weights to reduce loss.
# Types:
#
# SGD (Stochastic Gradient Descent): Updates weights step-by-step.
#
# Adam: Combines momentum and adaptive learning rates for faster convergence.
#
# RMSprop: Adjusts learning rate based on recent gradients.
#
# 19. What is sklearn.linear_model?
# sklearn.linear_model is a module in scikit-learn for linear models, like linear regression, logistic regression, and more.
#
# 20. What does model.fit() do? What arguments must be given?
# model.fit() trains the model on data.
# Arguments: model.fit(X_train, y_train)
#
# 21. What does model.predict() do? What arguments must be given?
# model.predict() makes predictions on new data.
# Arguments: model.predict(X_test)
#
# 22. What are continuous and categorical variables?
# Continuous: Numeric values (e.g., salary, age).
# Categorical: Categories or labels (e.g., country, product type).
#
# 23. What is feature scaling? How does it help in Machine Learning?
# Feature scaling brings all numeric values into the same range. It helps models (like distance-based algorithms) perform better.
#
# 24. How do we perform scaling in Python?
#
# Using StandardScaler or MinMaxScaler:
#
#
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# 25. What is sklearn.preprocessing?
# sklearn.preprocessing is a scikit-learn module with tools for:
#
# Encoding
#
# Scaling
#
# Transforming features
#
# 26. How do we split data for model fitting (training and testing) in Python?
# Using train_test_split():
#
#
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# 27. Explain data encoding.
# Data encoding converts categorical data into numeric form so that models can understand it.
# Common methods:
#
# Label Encoding: Assigns numbers to categories.
#
# One-Hot Encoding: Creates binary columns for each category.
